# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Tổng quan về mạng
# # Deep neural network notation: Ký hiệu mạng nơ-ron sâu.
#
# - 4 layer NN: Đây là một mạng nơ-ron có 4 lớp.
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# => chỉ khác với shallow neural network là có nhiều lớp hidden layer hơn còn về các khái niệm thì như nhau
