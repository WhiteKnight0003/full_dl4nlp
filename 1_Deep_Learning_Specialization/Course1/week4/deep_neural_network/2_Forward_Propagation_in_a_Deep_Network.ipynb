# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Công thức tổng quát

# %% [markdown]
# ![image-2.png](attachment:image-2.png)
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# # Ví dụ cho từng lớp
# ![image.png](attachment:image.png)
