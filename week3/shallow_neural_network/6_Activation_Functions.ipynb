# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # ví dụ nhé ở các bước để tính a[1] và a[2] thay vì hàm sigmoid thì ta có thể đổi sang hàm tanh , relu và loki relu không , có phải chia dạng để áp dụng các activation function không hay chỉ việc sử dụng những hàm mới như relu là hiệu quả sẽ cao hơn
#
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# # Trong 1 shallow neural network , tôi có thể áp dụng  activation function khác nhau ở các tầng không , ý tôi tức là thay vì chỉ có 1 activation thì có thể có nhiều hơn 1 được sử dụn không

# %% [markdown]
# - Trong Shallow Neural Network, bạn có thể áp dụng các activation function khác nhau ở các tầng, không nhất thiết phải chỉ dùng một loại duy nhất.
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# # ở phần lưu ý có phải bạn muốn nói với tôi đối với các tầng hidden , tôi nên dùng relu hoặc leaky relu để dễ trích xuất đặc trưng hơn , còn đến phần output thì tôi nên dựa vào loại bài toán để quyết định đúng không
#
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)
