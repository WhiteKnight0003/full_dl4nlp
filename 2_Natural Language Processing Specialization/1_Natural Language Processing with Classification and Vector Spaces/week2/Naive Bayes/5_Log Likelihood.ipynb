# %% [markdown]
# # ban đầu vẫn tính xác xuất của từng từ
# ![image.png](attachment:image.png)
#
# - positive là những từ có xác xuất > 1
# - các từ trung hòa có xác suát = 1
# - negative là các từ có xác xuất < 1

# %% [markdown]
# ![image.png](attachment:image.png)
# - do tính chất  log(a*b) = log(a)+ log(b) nên tất cả đang nhân chuyển hết thành cộng -> mới có tính tổng ở đây

# %% [markdown]
# # Summing the lambdas
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
# - log likelihood > 0 -> pos
# - log likelihood < 0 -> neg

# %% [markdown]
# # Summary
# ![image.png](attachment:image.png)

# %% [markdown]
# # Summary
# - log likelihood > 0 -> pos
# - log likelihood < 0 -> neg
# ![image.png](attachment:image.png)
