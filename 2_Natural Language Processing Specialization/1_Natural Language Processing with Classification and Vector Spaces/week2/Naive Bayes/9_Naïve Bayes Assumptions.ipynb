# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
# - ví dụ ta thấy rõ ràng trong câu đang nói mùa đông
# - nhưng naive bayes rõ ràng là 1 giả định "ngây thơ" - tất cả các đặc trưng (các từ) đều độc lập với nhau
# - hệ quả : bỏ qua mối quan hệ giữa các từ - làm mất đi 1 phần ngữa nghĩa và bối cảnh của ngôn ngữ tự nhiên

# %% [markdown]
# ![image.png](attachment:image.png)
# - hiệu suất của mô hình naive bayses bị ảnh hưởng đáng kể bởi tần suất xuất hiện của các từ trong lớp (của bộ trainning)
# -  Điều này có nghĩa là sự phân bổ dữ liệu sẽ tạo ra một thiên hướng cho mô hình. Ví dụ, trên Twitter, thông thường số lượng tweet tích cực sẽ nhiều hơn số lượng tweet tiêu cực.
# -
# - Hệ quả:
#     + Nếu một mô hình được huấn luyện trên dữ liệu Twitter thực tế (mất cân bằng), nó có thể có xu hướng dự đoán "tích cực" nhiều hơn một chút.
#     + Ngược lại, nhiều bộ dữ liệu "sạch" được cố tình làm cho cân bằng, với số lượng mẫu tích cực và tiêu cực bằng nhau. Một mô hình được huấn luyện trên dữ liệu này có thể hoạt động khác khi áp dụng vào thế giới thực, nơi dữ liệu "nhiễu" hơn và mất cân bằng
