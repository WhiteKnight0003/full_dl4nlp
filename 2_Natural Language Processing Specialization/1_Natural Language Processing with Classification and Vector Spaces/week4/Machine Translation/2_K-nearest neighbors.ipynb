# %% [markdown]
# ![image.png](attachment:image.png)
# - từ "hello" ta cần tìm ra vector từ tương tự với nó nhưng ở tiếng pháp

# %% [markdown]
# ![image.png](attachment:image.png)
# - ví dụ bạn có vài ng bạn và bạn muốn em khoảng cách của họ đến mình (sắp xếp chay)

# %% [markdown]
# ![image.png](attachment:image.png)
#
# - Vấn đề của cách tìm kiếm thông thường  là bạn sẽ tìm kiếm hết trong khu vực được khoanh tròn để tìm ra người gần với bạn nhất
#
# - -> Giải pháp thông minh: Dùng đường kẻ và Bảng băm (Hash Tables) - ( Băm nhạy cục bộ (Locality-Sensitive Hashing - LSH).)
# ![image-4.png](attachment:image-4.png)
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ![image.png](attachment:image.png)
