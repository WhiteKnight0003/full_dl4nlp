# %% [markdown]
# ![image.png](attachment:image.png)
# - bạn có các hình và bạn muốn xếp các hình tương tự nhau vào 1 hash

# %% [markdown]
# ![image.png](attachment:image.png)
# - ví dụ ở đây ta có 10 ngăn (10 buckets) từ 0 -> 9 và ta sẽ tính hash_value = num_input%num_of_buckets

# %% [markdown]
# ![image.png](attachment:image.png)
