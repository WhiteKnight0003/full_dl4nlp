# %% [markdown]
# # vocabulary building

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Data Segregation - phân chia dữ liệu

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Positive counts

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Negative Counts
# - 📌 Ý chính: Tương tự, đây là vector đặc trưng tần suất cho lớp "Tiêu cực". Các từ như "sad", "not" có tần suất cao hơn.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Word Frequency in Classes

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
