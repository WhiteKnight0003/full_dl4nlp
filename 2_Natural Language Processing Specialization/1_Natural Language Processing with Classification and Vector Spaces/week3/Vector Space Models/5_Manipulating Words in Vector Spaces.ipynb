# %% [markdown]
# ![image.png](attachment:image.png)
# - Manipulating word vectors là quá trình thực hiện các phép toán (thường là cộng và trừ) trên các vector đại diện cho từ để khám phá và suy ra các mối quan hệ ngữ nghĩa mới.
#
# - Ý tưởng cốt lõi là nếu các mối quan hệ trong thế giới thực được mã hóa một cách có ý nghĩa vào không gian vector, thì chúng ta có thể "tính toán" với các khái niệm.

# %% [markdown]
# ![image.png](attachment:image.png)
# - ví dụ bạn đã biết thủ đô của nước mĩ nhưng bạn đang chưa biết thủ đô của nga

# %% [markdown]
# ![image.png](attachment:image.png)
# - ban đầu bạn tính vị trí giữa usa và washington bạn sẽ được 1 vector mới là độ chênh giữa 2 điểm (gọi là vector v)
# - sau đó cho russia cộng với vector v ở trên sẽ ra 1 điểm mới (nó sẽ tính khoảng cách từ điểm dự đoán này đến các điểm khác , xem khoảng cách nào là min thì nó chọn )

# %% [markdown]
# ![image.png](attachment:image.png)
