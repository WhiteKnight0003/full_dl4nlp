# %% [markdown]
# ![image.png](attachment:image.png)
# - có 2 điểm A và B và ta sẽ tính khoảng các giữa chúng

# %% [markdown]
# ![image.png](attachment:image.png)
# - áp dụng vào không gian n-chiều - để tích khoảng cách giữa 2 vector bất kì w và v

# %% [markdown]
# # áp dụng vào code python
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
