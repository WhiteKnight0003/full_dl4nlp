# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Sự khác biệt chính là: Khoảng cách Euclidean đo lường khoảng cách "đường chim bay" và rất nhạy cảm với độ lớn (magnitude) của vector. Ngược lại, Độ tương đồng Cosine chỉ quan tâm đến hướng (direction) của vector và bỏ qua độ lớn của chúng
#
# - 📏 1. Khoảng cách Euclidean (Đo độ lớn) : Phương pháp này phù hợp khi độ lớn của các giá trị có ý nghĩa quan trọng.
# - 🧭 2. Độ tương đồng Cosine (Đo hướng) : Phương pháp này không quan tâm đến việc các vector dài hay ngắn, mà chỉ quan tâm xem chúng có chỉ về cùng một hướng hay không. Nó trả lời câu hỏi: "Hai vector này có định hướng giống nhau không?". Sự tương đồng được đo bằng cosin của góc giữa hai vector. Góc càng nhỏ, cosin càng gần 1, và độ tương đồng càng cao

# %% [markdown]
# ![image.png](attachment:image.png)
# - ta tính khoảng các d1, d2 giữa các vector như trong hình
# - với cosin - thì cos 0 = 1 , cos 90 = 0
# - thay vì so sánh độ dài giữa các vector , bây giờ bạn có thể thay thế = so sánh góc ()

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)
# ![image-3.png](attachment:image-3.png)
# - nếu beta = 90' hay cos(beta) = 0 => ta thấy 2 vector có hướng khác nhau
# - nếu beta = 0' hay cos(beta) = 1 => ta thấy 2 vector cùng hướng với nhau

# %% [markdown]
# ![image.png](attachment:image.png)
