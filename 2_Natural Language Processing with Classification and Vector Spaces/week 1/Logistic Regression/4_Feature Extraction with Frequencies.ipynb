# %% [markdown]
# # Feature Extraction Formula - công thức trích xuất đặc trưng

# %% [markdown]
# ![image.png](attachment:image.png)
# - Biến freqs là một cấu trúc dữ liệu (thường là một bảng hoặc từ điển) dùng để lưu trữ số lần xuất hiện (tần suất) của mỗi từ trong từng lớp cụ thể (ví dụ: lớp "tích cực" và lớp "tiêu cực").

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Sum of positive Frequencies

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Sum of negative Frequencies

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Final  feature vector - vector đặc trưng cuối cùng

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
