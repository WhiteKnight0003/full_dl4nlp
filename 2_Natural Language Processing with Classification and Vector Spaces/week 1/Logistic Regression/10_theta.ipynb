# %% [markdown]
# # thay vì làm theo các thông thường
# - với z = wt+b , bây giờ ta vector hóa lại

# %% [markdown]
# ![image-2.png](attachment:image-2.png)
# ![image.png](attachment:image.png)
# - Z - vẫn là tích vô hướng
# - còn ở Y là nhân

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)
# ![image-3.png](attachment:image-3.png)
# ![image-4.png](attachment:image-4.png)

# %% [markdown]
# # để ý

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Khởi tạo

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# # nhưng nếu mà khởi tạo ngẫu nhiên theta = 0 , có sợ nó gặp tình trạng của w trong hidden neural network là các lớp sẽ chỉ tính ra 1 giá trị không

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)
# - việc khởi tạo w hay theta = 0 chỉ dừng ở việc nó không có hidden layer , nhưng nếu nó có hidden layer thì mô hình sẽ k thể học được các feature
