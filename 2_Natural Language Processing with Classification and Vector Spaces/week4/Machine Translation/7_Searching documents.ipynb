# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# - cho 1 tài liệu : I love learning - chưa đc vector hóa
# - tách từng từ r vector hóa - sau đó công các vector hóa đó lại để có vector hóa cho cả câu
# - thực hiện K-NN để document search

# %% [markdown]
# ![image.png](attachment:image.png)
