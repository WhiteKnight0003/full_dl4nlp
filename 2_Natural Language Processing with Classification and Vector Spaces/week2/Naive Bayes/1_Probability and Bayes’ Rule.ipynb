# %% [markdown]
# ![image.png](attachment:image.png)
# - trong cả positive và negative đều có những tweet chứa từ happy

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-3.png](attachment:image-3.png)
