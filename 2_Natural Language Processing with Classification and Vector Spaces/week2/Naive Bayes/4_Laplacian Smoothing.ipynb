# %% [markdown]
# # dùng để giải quyết vấn đề khi bài toán bị Zero-Frequency Problem

# %% [markdown]
# ![image.png](attachment:image.png)
# - í là ở đây sẽ +1 lần xuất hiện cho tất cả các từ - để không còn cái nào bị = 0

# %% [markdown]
# # Ban đầu
# ![image.png](attachment:image.png)

# %% [markdown]
# # Sau khi laplace smoothing
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
# - 3 + 1 ở đây chính là 4 - số lần xuất hiện mới của từ I
# - tại sao v = 8 - chính là số từ trong word (bạn đếm thêm mỗi từ 1 lần trong pos và neg thì thằng tổng bắt buộc phải thêm tổng số từ trong word vào chứ )

# %% [markdown]
# ![image.png](attachment:image.png)
# - cuối cùng thu được 1 bảng mới và dòng because không còn bị = 0 nữa
