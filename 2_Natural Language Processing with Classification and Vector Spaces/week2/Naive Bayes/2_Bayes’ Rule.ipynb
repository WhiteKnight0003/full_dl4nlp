# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# - X là sự kiện "bạn thực sự mắc bệnh Pixelitis".
# - Y là sự kiện "bạn có kết quả xét nghiệm dương tính".
# - Chúng ta cần tìm P(X|Y), tức là xác suất bạn mắc bệnh khi đã biết kết quả là dương tính.
# - (P(Y|x) là bạn thật sự mắc bệnh thì xác xuất xét nghiệm dương tính là bao nhiêu )
