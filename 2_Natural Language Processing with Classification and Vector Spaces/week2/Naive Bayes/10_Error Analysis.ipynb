# %% [markdown]
# # Error Analysis
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image-2.png](attachment:image-2.png)
# - ví dụ dấu :( đang thể hiện sự buồn bã nếu bỏ nó đi trông nó sẽ bị hiểu sai thành pos

# %% [markdown]
# ![image.png](attachment:image.png)
# - hoặc khi bạn xóa bớt các từ trung lập đi nó sẽ trông như đang nói về pos

# %% [markdown]
# ![image.png](attachment:image.png)
# - thứ tự từ nó cũng rất quan trọng để giúp chúng ta phân biệt pos và neg

# %% [markdown]
# ![image.png](attachment:image.png)
# - Lỗi do ngôn ngữ phức tạp : con người có thể học nhanh còn máy tính thì không
# - Nói mỉa mai (Sarcasm)
# - Nói châm biếm (Irony)
# - Nói giảm nói tránh (Euphemisms)
# - các từ này rất dễ làm mô hình hiểu nhầm ý của câu từ đó đưa ra các dự đoán sai lầm
